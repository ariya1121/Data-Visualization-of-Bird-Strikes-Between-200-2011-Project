# %% [raw]
# Data Visualization of Bird Strikes between 2000 – 2011

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import seaborn as sns
sns.set_style('whitegrid')

# %%
df=pd.read_csv("C:\\Users\\Administrator\\Downloads\\UM Project 2\\Bird Strikes data.xlsx - Bird Strikes.csv")
df
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25559 entries, 0 to 25558
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25558 non-null  float64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25559 non-null  int64
#  7   Effect: Impact to flight                 2078 non-null   object
#  8   FlightDate                               25429 non-null  object
#  9   Effect: Indicated Damage                 25558 non-null  object
#  10  Aircraft: Number of engines?             25291 non-null  object
#  11  Aircraft: Airline/Operator               25429 non-null  object
#  12  Origin State                             25109 non-null  object
#  13  When: Phase of flight                    25429 non-null  object
#  14  Conditions: Precipitation                2015 non-null   object
#  15  Remains of wildlife collected?           25558 non-null  object
#  16  Remains of wildlife sent to Smithsonian  25558 non-null  object
#  17  Remarks                                  20787 non-null  object
#  18  Wildlife: Size                           25429 non-null  object
#  19  Conditions: Sky                          25558 non-null  object
#  20  Wildlife: Species                        25558 non-null  object
#  21  Pilot warned of birds or wildlife?       25429 non-null  object
#  22  Cost: Total $                            25558 non-null  object
#  23  Feet above ground                        25429 non-null  object
#  24  Number of people injured                 25558 non-null  float64
#  25  Is Aircraft Large?                       25429 non-null  object
# dtypes: float64(2), int64(1), object(23)
# memory usage: 5.1+ MB
# None

# %%
df.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  Number of people injured
# count   25558.000000                     25559.00000              25558.000000
# mean   253916.085609                         5.38284                  0.001056
# std     38510.453382                       430.45553                  0.050420
# min      1195.000000                         1.00000                  0.000000
# 25%    225783.750000                         1.00000                  0.000000
# 50%    248749.000000                         1.00000                  0.000000
# 75%    269168.750000                         1.00000                  0.000000
# max    321909.000000                     68790.00000                  6.000000

# %%
df.head()
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0   202152.0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1   208159.0       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2   207601.0       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3   215953.0       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4   219878.0       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight        FlightDate  \
# 0                             859         Engine Shut Down     11/23/00 0:00
# 1                             424                      NaN      7/25/01 0:00
# 2                             261                      NaN      9/14/01 0:00
# 3                             806    Precautionary Landing  09-05-2002 00:00
# 4                             942                      NaN      6/23/03 0:00
#
#   Effect: Indicated Damage  ... Remains of wildlife sent to Smithsonian  \
# 0            Caused damage  ...                                   False
# 1            Caused damage  ...                                   False
# 2                No damage  ...                                   False
# 3                No damage  ...                                   False
# 4                No damage  ...                                   False
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
# 2  FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER AP...          Small
# 3  NOTAM WARNING. 26 BIRDS HIT THE A/C, FORCING A...          Small
# 4                                      NO DMG REPTD.          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
# 2        No Cloud      European starling                                  N
# 3      Some Cloud      European starling                                  Y
# 4        No Cloud      European starling                                  N
#
#   Cost: Total $ Feet above ground Number of people injured Is Aircraft Large?
# 0        30,736             1,500                      0.0                Yes
# 1             0                 0                      0.0                 No
# 2             0                50                      0.0                 No
# 3             0                50                      0.0                Yes
# 4             0                50                      0.0                 No
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# Record ID                                      1
# Aircraft: Type                               130
# Airport: Name                                130
# Altitude bin                                 130
# Aircraft: Make/Model                           1
# Wildlife: Number struck                      130
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   23481
# FlightDate                                   130
# Effect: Indicated Damage                       1
# Aircraft: Number of engines?                 268
# Aircraft: Airline/Operator                   130
# Origin State                                 450
# When: Phase of flight                        130
# Conditions: Precipitation                  23544
# Remains of wildlife collected?                 1
# Remains of wildlife sent to Smithsonian        1
# Remarks                                     4772
# Wildlife: Size                               130
# Conditions: Sky                                1
# Wildlife: Species                              1
# Pilot warned of birds or wildlife?           130
# Cost: Total $                                  1
# Feet above ground                            130
# Number of people injured                       1
# Is Aircraft Large?                           130
# dtype: int64

# %%
df['Remarks'].unique()
# Out:
# array(['FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN TYPE. #1 ENG WAS SHUT DOWN AND DIVERTED TO EWR. SLIGHT VIBRATION. A/C WAS OUT OF SVC FOR REPAIRS TO COWLING, FAN DUCT ACCOUSTIC PANEL. INGESTION. DENTED FAN BLADE #26 IN #1 ENG. HEAVY BLOOD STAINS ON L WINGTIP',
#        '102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR WAS DAMAGED AND REPLACED.',
#        'FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER APCH END OF RWY. NO DMG. JUST A LOT OF BIRD DROPPINGS ON WINDSCREEN.',
#        ...,
#        'STRUCK BIRD ON RT FRONT DURING T/O. BIRD REPTD AS BROWN/WHITE. TWY.',
#        'PILOTS REPORT STRIKING UNKNOWN BIRD ON RWY 21L BTWN TWY F & J. NO REMAINS FOUND ON RWY OR ON A/C. NO DMG TO A/C.',
#        'HIT CENTER OF RADOME, CAVING IN ABOUT 12". RADOME WAS REPLACED. CARCASS FOUND IN SAFETY ARA ON RT SIDE OF RWY 22 AT INTXN OF RWY 18/36.'],
#       dtype=object)

# %%
df['Origin State'].unique()
# Out:
# array(['New York', 'Texas', 'Louisiana', 'Washington', 'Virginia', nan,
#        'Delaware', 'DC', 'Georgia', 'Florida', 'California', 'Illinois',
#        'Connecticut', 'Missouri', 'Rhode Island', 'Hawaii', 'Arizona',
#        'Tennessee', 'South Carolina', 'South Dakota', 'New Jersey',
#        'Colorado', 'Minnesota', 'Alabama', 'Ohio', 'Wisconsin',
#        'Michigan', 'Massachusetts', 'Alaska', 'North Carolina',
#        'Kentucky', 'Indiana', 'Oregon', 'Pennsylvania', 'New Hampshire',
#        'Arkansas', 'Nevada', 'Mississippi', 'Maryland', 'Maine', 'Quebec',
#        'Idaho', 'British Columbia', 'Utah', 'Nebraska', 'Iowa',
#        'New Mexico', 'West Virginia', 'Oklahoma', 'North Dakota',
#        'Vermont', 'Wyoming', 'Kansas', 'Prince Edward Island', 'Montana',
#        'Puerto Rico', 'Ontario', 'Virgin Islands',
#        'Newfoundland and Labrador', 'Alberta', 'Saskatchewan'],
#       dtype=object)

# %%
df['When: Phase of flight'].unique()
# Out:
# array(['Climb', 'Landing Roll', 'Approach', 'Take-off run', 'Descent',
#        nan, 'Taxi', 'Parked'], dtype=object)

# %%
df['Aircraft: Type'].unique()
# Out:
# array(['Airplane', nan], dtype=object)

# %%
df.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Remarks', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?'],
#       dtype='object')

# %%
df.size
# Out:
# 664534

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25559 entries, 0 to 25558
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25558 non-null  float64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25559 non-null  int64
#  7   Effect: Impact to flight                 2078 non-null   object
#  8   FlightDate                               25429 non-null  object
#  9   Effect: Indicated Damage                 25558 non-null  object
#  10  Aircraft: Number of engines?             25291 non-null  object
#  11  Aircraft: Airline/Operator               25429 non-null  object
#  12  Origin State                             25109 non-null  object
#  13  When: Phase of flight                    25429 non-null  object
#  14  Conditions: Precipitation                2015 non-null   object
#  15  Remains of wildlife collected?           25558 non-null  object
#  16  Remains of wildlife sent to Smithsonian  25558 non-null  object
#  17  Remarks                                  20787 non-null  object
#  18  Wildlife: Size                           25429 non-null  object
#  19  Conditions: Sky                          25558 non-null  object
#  20  Wildlife: Species                        25558 non-null  object
#  21  Pilot warned of birds or wildlife?       25429 non-null  object
#  22  Cost: Total $                            25558 non-null  object
#  23  Feet above ground                        25429 non-null  object
#  24  Number of people injured                 25558 non-null  float64
#  25  Is Aircraft Large?                       25429 non-null  object
# dtypes: float64(2), int64(1), object(23)
# memory usage: 5.1+ MB

# %%
df1 = df.copy()

# %%
df1
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0       202152.0       Airplane                     LAGUARDIA NY    > 1000 ft
# 1       208159.0       Airplane      DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2       207601.0       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3       215953.0       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4       219878.0       Airplane                     NORFOLK INTL    < 1000 ft
# ...          ...            ...                              ...          ...
# 25554   319677.0       Airplane                     ORLANDO INTL    < 1000 ft
# 25555   319680.0            NaN                              NaN          NaN
# 25556   319679.0       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557   319593.0       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
# 25558        NaN            NaN                              NaN          NaN
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 0                B-737-400                Over 100
# 1                    MD-80                Over 100
# 2                    C-500                Over 100
# 3                B-737-400                Over 100
# 4             CL-RJ100/200                Over 100
# ...                    ...                     ...
# 25554                A-321                       1
# 25555               EC-135                     NaN
# 25556            B-757-200                       1
# 25557            B-737-400                       1
# 25558                  NaN                     NaN
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  \
# 0                                 859         Engine Shut Down
# 1                                 424                      NaN
# 2                                 261                      NaN
# 3                                 806    Precautionary Landing
# 4                                 942                      NaN
# ...                               ...                      ...
# 25554                               1                      NaN
# 25555                               1                      NaN
# 25556                               1                      NaN
# 25557                               1                      NaN
# 25558                           68790                      NaN
#
#              FlightDate Effect: Indicated Damage  ...  \
# 0         11/23/00 0:00            Caused damage  ...
# 1          7/25/01 0:00            Caused damage  ...
# 2          9/14/01 0:00                No damage  ...
# 3      09-05-2002 00:00                No damage  ...
# 4          6/23/03 0:00                No damage  ...
# ...                 ...                      ...  ...
# 25554     12/30/11 0:00                No damage  ...
# 25555               NaN                No damage  ...
# 25556     12/31/11 0:00                No damage  ...
# 25557     12/31/11 0:00            Caused damage  ...
# 25558               NaN                      NaN  ...
#
#       Remains of wildlife sent to Smithsonian  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ...                                       ...
# 25554                                   False
# 25555                                   False
# 25556                                   False
# 25557                                   False
# 25558                                     NaN
#
#                                                  Remarks Wildlife: Size  \
# 0      FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1      102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
# 2      FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER AP...          Small
# 3      NOTAM WARNING. 26 BIRDS HIT THE A/C, FORCING A...          Small
# 4                                          NO DMG REPTD.          Small
# ...                                                  ...            ...
# 25554                                                NaN          Small
# 25555  STRUCK BIRD ON RT FRONT DURING T/O. BIRD REPTD...            NaN
# 25556  PILOTS REPORT STRIKING UNKNOWN BIRD ON RWY 21L...         Medium
# 25557  HIT CENTER OF RADOME, CAVING IN ABOUT 12". RAD...         Medium
# 25558                                                NaN            NaN
#
#       Conditions: Sky      Wildlife: Species  \
# 0            No Cloud  Unknown bird - medium
# 1          Some Cloud            Rock pigeon
# 2            No Cloud      European starling
# 3          Some Cloud      European starling
# 4            No Cloud      European starling
# ...               ...                    ...
# 25554      Some Cloud           Tree swallow
# 25555        No Cloud   Unknown bird - small
# 25556      Some Cloud  Unknown bird - medium
# 25557        No Cloud        Red-tailed hawk
# 25558             NaN                    NaN
#
#       Pilot warned of birds or wildlife? Cost: Total $ Feet above ground  \
# 0                                      N        30,736             1,500
# 1                                      Y             0                 0
# 2                                      N             0                50
# 3                                      Y             0                50
# 4                                      N             0                50
# ...                                  ...           ...               ...
# 25554                                  Y             0                 0
# 25555                                NaN             0               NaN
# 25556                                  Y             0                 0
# 25557                                  N             0                 0
# 25558                                NaN           NaN               NaN
#
#       Number of people injured Is Aircraft Large?
# 0                          0.0                Yes
# 1                          0.0                 No
# 2                          0.0                 No
# 3                          0.0                Yes
# 4                          0.0                 No
# ...                        ...                ...
# 25554                      0.0                 No
# 25555                      0.0                NaN
# 25556                      0.0                Yes
# 25557                      0.0                Yes
# 25558                      NaN                NaN
#
# [25559 rows x 26 columns]

# %%
df1.dropna(subset=['Aircraft: Type','Airport: Name', 'Altitude bin','Wildlife: Number struck','Effect: Impact to flight','FlightDate','Aircraft: Number of engines?','Aircraft: Airline/Operator','Origin State','When: Phase of flight','Wildlife: Size','Pilot warned of birds or wildlife?','Feet above ground','Is Aircraft Large?'],inplace=True)

# %%
df1.isnull().sum()
# Out:
# Record ID                                     0
# Aircraft: Type                                0
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                  0
# Aircraft: Airline/Operator                    0
# Origin State                                  0
# When: Phase of flight                         0
# Conditions: Precipitation                  1808
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                     146
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# Cost: Total $                                 0
# Feet above ground                             0
# Number of people injured                      0
# Is Aircraft Large?                            0
# dtype: int64

# %%
df1.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  Number of people injured
# count    1995.000000                     1995.000000               1995.000000
# mean   248514.085714                        6.016541                  0.010025
# std     34349.015175                       30.550766                  0.167283
# min    200058.000000                        1.000000                  0.000000
# 25%    221356.500000                        1.000000                  0.000000
# 50%    242265.000000                        1.000000                  0.000000
# 75%    263918.000000                        4.000000                  0.000000
# max    321172.000000                      859.000000                  6.000000

# %%
df1.drop(labels='Remarks', axis=1,inplace=True)

# %%
df1.isnull().sum()
# Out:
# Record ID                                     0
# Aircraft: Type                                0
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                  0
# Aircraft: Airline/Operator                    0
# Origin State                                  0
# When: Phase of flight                         0
# Conditions: Precipitation                  1808
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# Cost: Total $                                 0
# Feet above ground                             0
# Number of people injured                      0
# Is Aircraft Large?                            0
# dtype: int64

# %%
df1
# Out:
#        Record ID Aircraft: Type                   Airport: Name Altitude bin  \
# 0       202152.0       Airplane                    LAGUARDIA NY    > 1000 ft
# 3       215953.0       Airplane             SEATTLE-TACOMA INTL    < 1000 ft
# 6       221697.0       Airplane               NEW CASTLE COUNTY    < 1000 ft
# 7       236635.0       Airplane     WASHINGTON DULLES INTL ARPT    < 1000 ft
# 8       207369.0       Airplane                    ATLANTA INTL    < 1000 ft
# ...          ...            ...                             ...          ...
# 25485   319903.0       Airplane                PUNTA GORDA ARPT    < 1000 ft
# 25507   319548.0       Airplane                 SACRAMENTO INTL    > 1000 ft
# 25517   319962.0       Airplane             SALT LAKE CITY INTL    < 1000 ft
# 25527   319579.0       Airplane         SAN FRANCISCO INTL ARPT    < 1000 ft
# 25528   319582.0       Airplane  FORT LAUDERDALE/HOLLYWOOD INTL    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 0                B-737-400                Over 100
# 3                B-737-400                Over 100
# 6               LEARJET-25                Over 100
# 7                    A-320                Over 100
# 8                  DC-9-30                 2 to 10
# ...                    ...                     ...
# 25485            B-737-400                       1
# 25507            B-737-700                       1
# 25517                A-320                       1
# 25527         CL-RJ100/200                       1
# 25528            B-737-700                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  \
# 0                                 859         Engine Shut Down
# 3                                 806    Precautionary Landing
# 6                                 227                    Other
# 7                                 320                    Other
# 8                                   9         Aborted Take-off
# ...                               ...                      ...
# 25485                               1         Engine Shut Down
# 25507                               1                    Other
# 25517                               1         Aborted Take-off
# 25527                               1         Aborted Take-off
# 25528                               1         Engine Shut Down
#
#              FlightDate Effect: Indicated Damage  ...  \
# 0         11/23/00 0:00            Caused damage  ...
# 3      09-05-2002 00:00                No damage  ...
# 6          8/17/03 0:00            Caused damage  ...
# 7      03-01-2006 00:00            Caused damage  ...
# 8      01-06-2000 00:00                No damage  ...
# ...                 ...                      ...  ...
# 25485  12-03-2011 00:00            Caused damage  ...
# 25507  12-08-2011 00:00            Caused damage  ...
# 25517     12/14/11 0:00                No damage  ...
# 25527     12/17/11 0:00            Caused damage  ...
# 25528     12/18/11 0:00                No damage  ...
#
#       Remains of wildlife collected? Remains of wildlife sent to Smithsonian  \
# 0                              False                                   False
# 3                               True                                   False
# 6                               True                                    True
# 7                               True                                   False
# 8                              False                                   False
# ...                              ...                                     ...
# 25485                           True                                   False
# 25507                           True                                    True
# 25517                           True                                   False
# 25527                           True                                    True
# 25528                          False                                   False
#
#       Wildlife: Size Conditions: Sky            Wildlife: Species  \
# 0             Medium        No Cloud        Unknown bird - medium
# 3              Small      Some Cloud            European starling
# 6              Small        No Cloud            European starling
# 7              Small      Some Cloud            European starling
# 8              Small      Some Cloud                  Rock pigeon
# ...              ...             ...                          ...
# 25485          Large      Some Cloud               Sandhill crane
# 25507          Large        No Cloud  Greater white-fronted goose
# 25517         Medium        Overcast            Rough-legged hawk
# 25527         Medium        No Cloud              Red-tailed hawk
# 25528         Medium      Some Cloud                       Egrets
#
#       Pilot warned of birds or wildlife? Cost: Total $ Feet above ground  \
# 0                                      N        30,736             1,500
# 3                                      Y             0                50
# 6                                      N     14,81,711               150
# 7                                      Y     14,83,141               100
# 8                                      N             0                 0
# ...                                  ...           ...               ...
# 25485                                  N             0                 0
# 25507                                  Y             0             2,200
# 25517                                  Y             0                 0
# 25527                                  N             0                 0
# 25528                                  Y             0                 0
#
#       Number of people injured Is Aircraft Large?
# 0                          0.0                Yes
# 3                          0.0                Yes
# 6                          0.0                 No
# 7                          0.0                 No
# 8                          0.0                 No
# ...                        ...                ...
# 25485                      0.0                Yes
# 25507                      0.0                Yes
# 25517                      0.0                 No
# 25527                      0.0                 No
# 25528                      0.0                Yes
#
# [1995 rows x 25 columns]

# %%
df1.to_excel(r'C:\\Users\\Administrator\\Downloads\\UM Project 2\\birdstrike_cleaned.xlsx',index = False)
